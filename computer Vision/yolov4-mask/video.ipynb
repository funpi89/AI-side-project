# %%
from yolo import YOLO
from PIL import Image
import numpy as np
import cv2
import time
yolo = YOLO()
# 调用摄像头
capture=cv2.VideoCapture(0) # capture=cv2.VideoCapture("1.mp4")
yolo.
fps = 0.0
while(True):
    t1 = time.time()
    # 读取某一帧
    ref,frame=capture.read()
    # 格式转变，BGRtoRGB
    frame = cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)
    # 转变成Image
    frame = Image.fromarray(np.uint8(frame))

    # 进行检测
    frame = np.array(yolo.detect_image(frame))

    # RGBtoBGR满足opencv显示格式
    frame = cv2.cvtColor(frame,cv2.COLOR_RGB2BGR)

    fps  = ( fps + (1./(time.time()-t1)) ) / 2
#     print("fps= %.2f"%(fps))
    frame = cv2.putText(frame, "fps= %.2f"%(fps), (0, 40), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

    cv2.imshow("video",frame)


#     c= cv2.waitKey(30) & 0xff 
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
capture.release()
cv2.destroyAllWindows()
# Out:
# C:\Users\a0922\AppData\Roaming\Python\Python37\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\a0922\AppData\Roaming\Python\Python37\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
# C:\Users\a0922\AppData\Roaming\Python\Python37\site-packages\numpy\.libs\libopenblas.TXA6YQSD3GCQQC22GEQ54J2UDCXDXHWN.gfortran-win_amd64.dll
#   stacklevel=1)
# Loading weights into state dict...
# Finished!
# logs/Epoch16-Val_Loss11.0234.pth model, anchors, and classes loaded.
# (2, 4)
# b'unwear 0.84'
# b'wear 0.60'
# fps= 0.05
# (0, 4)
# fps= 2.54
# (0, 4)
# fps= 4.04
# (0, 4)
# fps= 4.94
# (0, 4)
# fps= 5.38
# (0, 4)
# fps= 5.69
# (1, 4)
# b'wear 0.51'
# fps= 5.71
# (1, 4)
# b'wear 0.61'
# fps= 5.75
# (1, 4)
# b'wear 0.57'
# fps= 5.79
# (1, 4)
# b'wear 0.59'
# fps= 5.64
# (1, 4)
# b'wear 0.56'
# fps= 5.67
# (1, 4)
# b'wear 0.62'
# fps= 5.73
# (1, 4)
# b'wear 0.60'
# fps= 5.77
# (1, 4)
# b'wear 0.64'
# fps= 5.79
# (1, 4)
# b'wear 0.62'
# fps= 5.83
# (1, 4)
# b'wear 0.65'
# fps= 5.84
# (1, 4)
# b'wear 0.64'
# fps= 5.69
# (1, 4)
# b'wear 0.63'
# fps= 5.74
# (1, 4)
# b'wear 0.64'
# fps= 5.74
# (1, 4)
# b'wear 0.64'
# fps= 5.70
# (1, 4)
# b'wear 0.65'
# fps= 5.46
# (1, 4)
# b'wear 0.62'
# fps= 5.49
# (1, 4)
# b'wear 0.63'
# fps= 5.41
# (1, 4)
# b'wear 0.63'
# fps= 5.36
# (1, 4)
# b'wear 0.63'
# fps= 5.56
# (1, 4)
# b'wear 0.62'
# fps= 5.72
# (1, 4)
# b'wear 0.62'
# fps= 5.81
# (1, 4)
# b'wear 0.63'
# fps= 5.87
# (1, 4)
# b'wear 0.63'
# fps= 5.90
# (1, 4)
# b'wear 0.63'
# fps= 5.90
# (1, 4)
# b'wear 0.64'
# fps= 5.91
# (1, 4)
# b'wear 0.63'
# fps= 5.88
# (1, 4)
# b'wear 0.62'
# fps= 5.61
# (1, 4)
# b'wear 0.63'
# fps= 5.47
# (1, 4)
# b'wear 0.63'
# fps= 5.52
# (1, 4)
# b'wear 0.63'
# fps= 5.66
# (1, 4)
# b'wear 0.62'
# fps= 5.73
# (1, 4)
# b'wear 0.63'
# fps= 5.72
# (1, 4)
# b'wear 0.63'
# fps= 5.74
# (1, 4)
# b'wear 0.62'
# fps= 5.65
# (1, 4)
# b'wear 0.62'
# fps= 5.78
# (1, 4)
# b'wear 0.64'
# fps= 5.84
# (1, 4)
# b'wear 0.62'
# fps= 5.87
# (1, 4)
# b'wear 0.63'
# fps= 5.95
# (1, 4)
# b'wear 0.61'
# fps= 5.87
# (1, 4)
# b'wear 0.61'
# fps= 5.88
# (1, 4)
# b'wear 0.60'
# fps= 5.90
# (1, 4)
# b'wear 0.60'
# fps= 5.85
# (1, 4)
# b'wear 0.59'
# fps= 5.68
# (1, 4)
# b'wear 0.58'
# fps= 5.81
# (1, 4)
# b'wear 0.57'
# fps= 5.85
# (1, 4)
# b'wear 0.54'
# fps= 5.81
# (1, 4)
# b'wear 0.59'
# fps= 5.90
# (1, 4)
# b'wear 0.56'
# fps= 5.80
# (0, 4)
# fps= 5.91
# (1, 4)
# b'wear 0.57'
# fps= 5.87
# (0, 4)
# fps= 5.94
# (0, 4)
# fps= 5.98
# (0, 4)
# fps= 5.95
# (1, 4)
# b'wear 0.52'
# fps= 5.95
# (0, 4)
# fps= 5.96
# (1, 4)
# b'wear 0.52'
# fps= 5.90
# (0, 4)
# fps= 5.92
# (1, 4)
# b'wear 0.56'
# fps= 5.88
# (1, 4)
# b'wear 0.56'
# fps= 5.87
# (1, 4)
# b'wear 0.55'
# fps= 5.92
# (1, 4)
# b'wear 0.51'
# fps= 5.91
# (0, 4)
# fps= 5.90
# (0, 4)
# fps= 5.97
# (0, 4)
# fps= 5.76
# (0, 4)
# fps= 5.88
# (0, 4)
# fps= 5.96
# (0, 4)
# fps= 6.00
# (0, 4)
# fps= 5.74
# (0, 4)
# fps= 5.88
# (0, 4)
# fps= 5.89
# (0, 4)
# fps= 5.95
# (0, 4)
# fps= 5.98
# (0, 4)
# fps= 5.99
# (1, 4)
# b'wear 0.57'
# fps= 5.90
# (1, 4)
# b'wear 0.60'
# fps= 5.94
# (2, 4)
# b'unwear 0.84'
# b'wear 0.57'
# fps= 5.72
# (2, 4)
# b'unwear 0.83'
# b'wear 0.50'
# fps= 5.63
# (1, 4)
# b'unwear 0.89'
# fps= 5.68
# (1, 4)
# b'unwear 0.89'
# fps= 5.78
# (1, 4)
# b'unwear 0.90'
# fps= 5.84
# (1, 4)
# b'unwear 0.89'
# fps= 5.84
# (1, 4)
# b'unwear 0.89'
# fps= 5.93
# (1, 4)
# b'unwear 0.90'
# fps= 5.88
# (1, 4)
# b'unwear 0.90'
# fps= 5.86
# (1, 4)
# b'unwear 0.91'
# fps= 5.84
# (1, 4)
# b'unwear 0.90'
# fps= 5.91
# (1, 4)
# b'unwear 0.91'
# fps= 5.89
# (1, 4)
# b'unwear 0.90'
# fps= 5.91
# (1, 4)
# b'unwear 0.87'
# fps= 5.84
# (1, 4)
# b'unwear 0.84'
# fps= 5.77
# (2, 4)
# b'unwear 0.88'
# b'wear 0.58'
# fps= 5.74
# (2, 4)
# b'unwear 0.61'
# b'wear 0.60'
# fps= 5.75
# (1, 4)
# b'wear 0.62'
# fps= 5.87
# (2, 4)
# b'unwear 0.69'
# b'wear 0.61'
# fps= 5.87
# (1, 4)
# b'wear 0.59'
# fps= 5.81
# (1, 4)
# b'wear 0.56'
# fps= 5.87
# (1, 4)
# b'wear 0.57'
# fps= 5.77
# (1, 4)
# b'wear 0.58'
# fps= 5.82
# (1, 4)
# b'wear 0.58'
# fps= 5.84
# (1, 4)
# b'wear 0.59'
# fps= 5.84
# (2, 4)
# b'unwear 0.55'
# b'wear 0.59'
# fps= 5.58
# (1, 4)
# b'wear 0.59'
# fps= 5.74
# (2, 4)
# b'unwear 0.51'
# b'wear 0.62'
# fps= 5.74
# (2, 4)
# b'unwear 0.87'
# b'wear 0.64'
# fps= 5.67
# (2, 4)
# b'unwear 0.93'
# b'wear 0.60'
# fps= 5.57
# (1, 4)
# b'unwear 0.87'
# fps= 5.53
# (1, 4)
# b'unwear 0.89'
# fps= 5.49
# (1, 4)
# b'unwear 0.88'
# fps= 5.41
# (1, 4)
# b'unwear 0.87'
# fps= 5.43
# (1, 4)
# b'unwear 0.88'
# fps= 5.56
# (1, 4)
# b'unwear 0.90'
# fps= 5.65
# (1, 4)
# b'unwear 0.90'
# fps= 5.75
# (1, 4)
# b'unwear 0.91'
# fps= 5.71
# (1, 4)
# b'unwear 0.90'
# fps= 5.70
# (1, 4)
# b'unwear 0.93'
# fps= 5.67
# (1, 4)
# b'unwear 0.91'
# fps= 5.68
# (1, 4)
# b'unwear 0.91'
# fps= 5.71
# (1, 4)
# b'unwear 0.91'
# fps= 5.72
# (1, 4)
# b'unwear 0.90'
# fps= 5.74
# (1, 4)
# b'unwear 0.93'
# fps= 5.70
# (1, 4)
# b'unwear 0.89'
# fps= 5.79
# (1, 4)
# b'unwear 0.85'
# fps= 5.78
# (1, 4)
# b'unwear 0.91'
# fps= 5.79
# (1, 4)
# b'unwear 0.87'
# fps= 5.78
# (1, 4)
# b'unwear 0.87'
# fps= 5.77
# (1, 4)
# b'unwear 0.89'
# fps= 5.78
# (1, 4)
# b'unwear 0.87'
# fps= 5.84
# (1, 4)
# b'unwear 0.88'
# fps= 5.87
# (1, 4)
# b'unwear 0.89'
# fps= 5.89
# (1, 4)
# b'unwear 0.89'
# fps= 5.68
# (1, 4)
# b'unwear 0.89'
# fps= 5.77
# (1, 4)
# b'unwear 0.83'
# fps= 5.81
# (1, 4)
# b'unwear 0.80'
# fps= 5.88
# (1, 4)
# b'unwear 0.80'
# fps= 5.88
# (1, 4)
# b'unwear 0.81'
# fps= 5.82
# (1, 4)
# b'unwear 0.81'
# fps= 5.79
# (1, 4)
# b'unwear 0.88'
# fps= 5.69
# (1, 4)
# b'unwear 0.78'
# fps= 5.81
# (1, 4)
# b'unwear 0.76'
# fps= 5.72
# (1, 4)
# b'wear 0.56'
# fps= 5.79
# (0, 4)
# fps= 5.78
# (1, 4)
# b'wear 0.59'
# fps= 5.66
# (1, 4)
# b'wear 0.56'
# fps= 5.73
# (1, 4)
# b'wear 0.56'
# fps= 5.81
# (1, 4)
# b'wear 0.63'
# fps= 5.86
# (1, 4)
# b'wear 0.58'
# fps= 5.83
# (1, 4)
# b'wear 0.53'
# fps= 5.92
# (1, 4)
# b'wear 0.68'
# fps= 5.88
# (1, 4)
# b'wear 0.75'
# fps= 5.85
# (1, 4)
# b'wear 0.70'
# fps= 5.58
# (1, 4)
# b'wear 0.69'
# fps= 5.76
# (1, 4)
# b'wear 0.68'
# fps= 5.80
# (1, 4)
# b'wear 0.60'
# fps= 5.85
# (1, 4)
# b'wear 0.72'
# fps= 5.82
# (1, 4)
# b'wear 0.73'
# fps= 5.86
# (1, 4)
# b'wear 0.74'
# fps= 5.86
# (1, 4)
# b'wear 0.74'
# fps= 5.86
# (1, 4)
# b'wear 0.76'
# fps= 5.83
# (1, 4)
# b'wear 0.77'
# fps= 5.79
# (1, 4)
# b'wear 0.81'
# fps= 5.88
# (1, 4)
# b'wear 0.82'
# fps= 5.88
# (1, 4)
# b'wear 0.80'
# fps= 5.89
# (1, 4)
# b'wear 0.80'
# fps= 5.90
# (1, 4)
# b'wear 0.81'
# fps= 5.85
# (1, 4)
# b'wear 0.78'
# fps= 5.84
# (1, 4)
# b'wear 0.78'
# fps= 5.84
# (1, 4)
# b'wear 0.79'
# fps= 5.87
# (1, 4)
# b'wear 0.77'
# fps= 5.90
# (1, 4)
# b'wear 0.77'
# fps= 5.90
# (1, 4)
# b'wear 0.73'
# fps= 5.92
# (1, 4)
# b'wear 0.73'
# fps= 5.95
# (1, 4)
# b'wear 0.85'
# fps= 5.87
# (1, 4)
# b'wear 0.78'
# fps= 5.89
# (1, 4)
# b'wear 0.81'
# fps= 5.81
# (1, 4)
# b'wear 0.76'
# fps= 5.81
# (1, 4)
# b'wear 0.71'
# fps= 5.84
# (1, 4)
# b'wear 0.76'
# fps= 5.89
# (1, 4)
# b'wear 0.70'
# fps= 5.92
# (1, 4)
# b'wear 0.67'
# fps= 5.91
# (1, 4)
# b'wear 0.72'
# fps= 5.89
# (1, 4)
# b'wear 0.68'
# fps= 5.92
# (1, 4)
# b'wear 0.67'
# fps= 5.88
# (1, 4)
# b'wear 0.66'
# fps= 5.69
# (1, 4)
# b'wear 0.76'
# fps= 5.68
# (1, 4)
# b'wear 0.73'
# fps= 5.58
# (1, 4)
# b'wear 0.79'
# fps= 5.58
# (1, 4)
# b'wear 0.82'
# fps= 5.72
# (1, 4)
# b'wear 0.78'
# fps= 5.79
# (1, 4)
# b'wear 0.77'
# fps= 5.81
# (1, 4)
# b'wear 0.76'
# fps= 5.81
# (1, 4)
# b'wear 0.72'
# fps= 5.85
# (1, 4)
# b'wear 0.62'
# fps= 5.80
# (1, 4)
# b'wear 0.51'
# fps= 5.85
# (0, 4)
# fps= 5.74
# (1, 4)
# b'wear 0.62'
# fps= 5.74
# (1, 4)
# b'wear 0.60'
# fps= 5.65
# (0, 4)
# fps= 5.81
# (0, 4)
# fps= 5.71
# (1, 4)
# b'wear 0.66'
# fps= 5.80
# (0, 4)
# fps= 5.80
# (0, 4)
# fps= 5.88
# (0, 4)
# fps= 5.81
# (1, 4)
# b'wear 0.50'
# fps= 5.84
# (1, 4)
# b'wear 0.51'
# fps= 5.84
# (1, 4)
# b'wear 0.52'
# fps= 5.80
# (1, 4)
# b'wear 0.51'
# fps= 5.80
# (1, 4)
# b'wear 0.52'
# fps= 5.83
# (1, 4)
# b'wear 0.53'
# fps= 5.82
# (1, 4)
# b'wear 0.50'
# fps= 5.76
# (1, 4)
# b'wear 0.50'
# fps= 5.67
# (0, 4)
# fps= 5.72
# (1, 4)
# b'wear 0.52'
# fps= 5.81
# (0, 4)
# fps= 5.91
# (0, 4)
# fps= 5.89
# (1, 4)
# b'wear 0.61'
# fps= 5.90
# (0, 4)
# fps= 5.97
# (0, 4)
# fps= 5.99
# (0, 4)
# fps= 5.98
# (1, 4)
# b'wear 0.50'
# fps= 5.89
# (1, 4)
# b'wear 0.50'
# fps= 5.89
# (0, 4)
# fps= 5.90
# (0, 4)
# fps= 5.92
# (0, 4)
# fps= 5.97
# (0, 4)
# fps= 5.93
# (0, 4)
# fps= 5.88
# (1, 4)
# b'wear 0.61'
# fps= 5.87
# (1, 4)
# b'wear 0.61'
# fps= 5.79
# (1, 4)
# b'wear 0.58'
# fps= 5.76
# (1, 4)
# b'wear 0.58'
# fps= 5.83
# (0, 4)
# fps= 5.90
# (1, 4)
# b'wear 0.61'
# fps= 5.83
# (1, 4)
# b'wear 0.61'
# fps= 5.83
# (1, 4)
# b'wear 0.62'
# fps= 5.85
# (1, 4)
# b'wear 0.62'
# fps= 5.80
# (1, 4)
# b'wear 0.61'
# fps= 5.81
# (1, 4)
# b'wear 0.63'
# fps= 5.89
# (1, 4)
# b'wear 0.63'
# fps= 5.93
# (1, 4)
# b'wear 0.69'
# fps= 5.90
# (1, 4)
# b'wear 0.55'
# fps= 5.90
# (1, 4)
# b'wear 0.57'
# fps= 5.87
# (1, 4)
# b'wear 0.58'
# fps= 5.79
# (1, 4)
# b'wear 0.60'
# fps= 5.78
# (1, 4)
# b'wear 0.61'
# fps= 5.74
# (1, 4)
# b'wear 0.78'
# fps= 5.64
# (0, 4)
# fps= 5.77
# (1, 4)
# b'wear 0.68'
# fps= 5.85
# (1, 4)
# b'wear 0.53'
# fps= 5.88
# (1, 4)
# b'wear 0.53'
# fps= 5.84
# (1, 4)
# b'wear 0.74'
# fps= 5.85
# (1, 4)
# b'wear 0.77'
# fps= 5.86
# (1, 4)
# b'wear 0.58'
# fps= 5.85
# (1, 4)
# b'wear 0.61'
# fps= 5.83
# (1, 4)
# b'wear 0.60'
# fps= 5.80
# (1, 4)
# b'wear 0.60'
# fps= 5.80
# (1, 4)
# b'wear 0.61'
# fps= 5.87
# (2, 4)
# b'unwear 0.54'
# b'wear 0.57'
# fps= 5.78
# (1, 4)
# b'wear 0.59'
# fps= 5.85
# (1, 4)
# b'wear 0.60'
# fps= 5.88
# (1, 4)
# b'wear 0.84'
# fps= 5.89
# (1, 4)
# b'wear 0.53'
# fps= 5.92
# (1, 4)
# b'wear 0.60'
# fps= 5.90
# (1, 4)
# b'wear 0.61'
# fps= 5.80
# (1, 4)
# b'wear 0.62'
# fps= 5.89
# (1, 4)
# b'wear 0.58'
# fps= 5.94
# (1, 4)
# b'wear 0.81'
# fps= 5.92
# (1, 4)
# b'wear 0.56'
# fps= 5.88
# (1, 4)
# b'wear 0.52'
# fps= 5.91
# (1, 4)
# b'wear 0.52'
# fps= 5.94
# (1, 4)
# b'wear 0.56'
# fps= 5.79
# (1, 4)
# b'wear 0.57'
# fps= 5.71
# (1, 4)
# b'wear 0.60'
# fps= 5.69
# (1, 4)
# b'wear 0.85'
# fps= 5.82
# (1, 4)
# b'wear 0.77'
# fps= 5.83
# (0, 4)
# fps= 5.89
# (0, 4)
# fps= 5.93
# (0, 4)
# fps= 5.90
# (1, 4)
# b'wear 0.71'
# fps= 5.90
# (2, 4)
# b'unwear 0.53'
# b'wear 0.66'
# fps= 5.78
# (1, 4)
# b'unwear 0.57'
# fps= 5.78
# (2, 4)
# b'unwear 0.54'
# b'wear 0.57'
# fps= 5.81
# (2, 4)
# b'unwear 0.59'
# b'wear 0.58'
# fps= 5.82
# (2, 4)
# b'unwear 0.58'
# b'wear 0.57'
# fps= 5.76
# (2, 4)
# b'unwear 0.77'
# b'wear 0.55'
# fps= 5.74
# (1, 4)
# b'wear 0.55'
# fps= 5.78
# (2, 4)
# b'unwear 0.52'
# b'wear 0.66'
# fps= 5.82
# (2, 4)
# b'unwear 0.57'
# b'wear 0.65'
# fps= 5.66
# (1, 4)
# b'wear 0.53'
# fps= 5.66
# (1, 4)
# b'wear 0.53'
# fps= 5.65
# (0, 4)
# fps= 5.70
# (0, 4)
# fps= 5.73
# (1, 4)
# b'wear 0.54'
# fps= 5.83
# (1, 4)
# b'wear 0.59'
# fps= 5.88
# (1, 4)
# b'wear 0.61'
# fps= 5.88
# (1, 4)
# b'wear 0.60'
# fps= 5.85
# (1, 4)
# b'wear 0.61'
# fps= 5.81
# (1, 4)
# b'wear 0.61'
# fps= 5.84
# (1, 4)
# b'wear 0.62'
# fps= 5.80
# (1, 4)
# b'wear 0.63'
# fps= 5.78
# (1, 4)
# b'wear 0.62'
# fps= 5.76
# (1, 4)
# b'wear 0.62'
# fps= 5.84
# (1, 4)
# b'wear 0.61'
# fps= 5.84
# (1, 4)
# b'wear 0.60'
# fps= 5.79
# (1, 4)
# b'wear 0.58'
# fps= 5.79
# (1, 4)
# b'wear 0.58'
# fps= 5.81
# (1, 4)
# b'wear 0.59'
# fps= 5.82
# (1, 4)
# b'wear 0.58'
# fps= 5.87
# (1, 4)
# b'wear 0.59'
# fps= 5.84
# (1, 4)
# b'wear 0.58'
# fps= 5.87
# (1, 4)
# b'wear 0.58'
# fps= 5.91
# (1, 4)
# b'wear 0.58'
# fps= 5.87

# %%
from yolo_voc import YOLO
from PIL import Image
import numpy as np
import cv2
import time
yolo = YOLO()
# 调用摄像头
capture=cv2.VideoCapture(0) # capture=cv2.VideoCapture("1.mp4")
fps = 0.0
while(True):
    t1 = time.time()
    # 读取某一帧
    ref,frame=capture.read()
    # 格式转变，BGRtoRGB
    frame = cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)
    # 转变成Image
    frame = Image.fromarray(np.uint8(frame))

    # 进行检测
    frame = np.array(yolo.detect_image(frame))

    # RGBtoBGR满足opencv显示格式
    frame = cv2.cvtColor(frame,cv2.COLOR_RGB2BGR)

    fps  = ( fps + (1./(time.time()-t1)) ) / 2
#     print("fps= %.2f"%(fps))
    frame = cv2.putText(frame, "fps= %.2f"%(fps), (0, 40), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

    cv2.imshow("video",frame)


#     c= cv2.waitKey(30) & 0xff 
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
capture.release()
cv2.destroyAllWindows()
# Out:
# C:\Users\a0922\AppData\Roaming\Python\Python37\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\a0922\AppData\Roaming\Python\Python37\site-packages\numpy\.libs\libopenblas.PYQHXLVVQ7VESDPUVUADXEVJOBGHJPAY.gfortran-win_amd64.dll
# C:\Users\a0922\AppData\Roaming\Python\Python37\site-packages\numpy\.libs\libopenblas.TXA6YQSD3GCQQC22GEQ54J2UDCXDXHWN.gfortran-win_amd64.dll
#   stacklevel=1)
# Loading weights into state dict...
# Finished!
# model_data/yolo4_voc_weights.pth model, anchors, and classes loaded.
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 1.00'
# (2, 4)
# b'chair 0.59'
# b'person 0.99'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (2, 4)
# b'person 0.99'
# b'person 0.96'
# (1, 4)
# b'person 0.98'
# (1, 4)
# b'person 0.83'
# (1, 4)
# b'person 0.79'
# (1, 4)
# b'person 0.84'
# (1, 4)
# b'person 0.81'
# (1, 4)
# b'person 0.82'
# (1, 4)
# b'person 0.71'
# (1, 4)
# b'person 0.70'
# (1, 4)
# b'person 0.60'
# (1, 4)
# b'person 0.52'
# (1, 4)
# b'person 0.71'
# (1, 4)
# b'person 0.72'
# (1, 4)
# b'person 0.77'
# (1, 4)
# b'person 0.73'
# (1, 4)
# b'person 0.74'
# (1, 4)
# b'person 0.73'
# (1, 4)
# b'person 0.62'
# (1, 4)
# b'person 0.86'
# (1, 4)
# b'person 0.85'
# (1, 4)
# b'person 0.82'
# (1, 4)
# b'person 0.87'
# (1, 4)
# b'person 0.83'
# (1, 4)
# b'person 0.81'
# (1, 4)
# b'person 0.84'
# (1, 4)
# b'person 0.86'
# (1, 4)
# b'person 0.80'
# (1, 4)
# b'person 0.81'
# (1, 4)
# b'person 0.90'
# (1, 4)
# b'person 0.67'
# (1, 4)
# b'person 0.96'
# (2, 4)
# b'person 0.98'
# b'person 0.66'
# (1, 4)
# b'person 0.98'
# (3, 4)
# b'bottle 0.54'
# b'person 0.98'
# b'person 0.64'
# (2, 4)
# b'person 1.00'
# b'person 0.98'
# (2, 4)
# b'person 1.00'
# b'person 0.86'
# (2, 4)
# b'person 1.00'
# b'person 0.97'
# (2, 4)
# b'person 1.00'
# b'person 0.55'
# (2, 4)
# b'person 1.00'
# b'person 0.79'
# (2, 4)
# b'person 1.00'
# b'person 0.98'
# (1, 4)
# b'person 0.99'
# (2, 4)
# b'person 1.00'
# b'person 0.50'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.97'
# (1, 4)
# b'person 0.95'
# (2, 4)
# b'bottle 0.61'
# b'person 0.97'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 1.00'
# (2, 4)
# b'person 1.00'
# b'person 0.91'
# (2, 4)
# b'person 1.00'
# b'person 0.93'
# (2, 4)
# b'person 1.00'
# b'person 0.70'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (2, 4)
# b'person 1.00'
# b'person 0.65'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (2, 4)
# b'person 1.00'
# b'person 0.74'
# (2, 4)
# b'person 1.00'
# b'person 0.92'
# (2, 4)
# b'person 1.00'
# b'person 0.95'
# (3, 4)
# b'bottle 0.53'
# b'person 1.00'
# b'person 0.94'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (2, 4)
# b'bottle 0.52'
# b'person 1.00'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 1.00'
# (2, 4)
# b'person 1.00'
# b'person 0.83'
# (2, 4)
# b'bottle 0.68'
# b'person 1.00'
# (2, 4)
# b'bottle 0.75'
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (2, 4)
# b'bottle 0.51'
# b'person 1.00'
# (2, 4)
# b'bottle 0.86'
# b'person 1.00'
# (2, 4)
# b'bottle 0.91'
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.98'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.98'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (2, 4)
# b'person 1.00'
# b'person 0.96'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.98'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (2, 4)
# b'person 1.00'
# b'person 0.99'
# (2, 4)
# b'person 1.00'
# b'person 0.76'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (2, 4)
# b'person 1.00'
# b'person 0.70'
# (2, 4)
# b'person 1.00'
# b'person 0.62'
# (2, 4)
# b'person 1.00'
# b'person 0.93'
# (2, 4)
# b'person 1.00'
# b'person 0.85'
# (2, 4)
# b'person 1.00'
# b'person 0.74'
# (1, 4)
# b'person 1.00'
# (2, 4)
# b'person 1.00'
# b'person 0.84'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (2, 4)
# b'chair 0.56'
# b'person 0.99'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 0.95'
# (1, 4)
# b'tvmonitor 0.68'
# (3, 4)
# b'person 0.88'
# b'person 0.80'
# b'tvmonitor 0.93'
# (3, 4)
# b'person 0.99'
# b'person 0.95'
# b'tvmonitor 0.78'
# (3, 4)
# b'person 0.98'
# b'person 0.96'
# b'tvmonitor 0.77'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.78'
# (3, 4)
# b'person 0.99'
# b'person 0.71'
# b'tvmonitor 0.90'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.91'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.90'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.69'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.68'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.66'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.67'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.92'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.89'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.73'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.85'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.95'
# (1, 4)
# b'person 0.99'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.89'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.95'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.79'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.98'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.98'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.94'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.95'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.94'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.97'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.96'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.95'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.97'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.92'
# (1, 4)
# b'person 0.99'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.52'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.80'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.52'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.50'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.73'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (2, 4)
# b'person 0.99'
# b'person 0.66'
# (2, 4)
# b'person 0.99'
# b'person 0.74'
# (2, 4)
# b'person 1.00'
# b'person 0.99'
# (2, 4)
# b'person 1.00'
# b'person 0.99'
# (2, 4)
# b'person 1.00'
# b'person 0.99'
# (2, 4)
# b'person 0.99'
# b'person 0.99'
# (2, 4)
# b'person 1.00'
# b'person 0.99'
# (2, 4)
# b'person 0.99'
# b'person 0.99'
# (2, 4)
# b'person 1.00'
# b'person 0.99'
# (2, 4)
# b'person 1.00'
# b'person 0.99'
# (2, 4)
# b'person 0.99'
# b'person 0.91'
# (2, 4)
# b'person 0.99'
# b'person 0.98'
# (2, 4)
# b'person 0.99'
# b'person 0.98'
# (2, 4)
# b'person 0.99'
# b'person 0.96'
# (2, 4)
# b'person 0.99'
# b'person 0.99'
# (3, 4)
# b'person 0.99'
# b'person 0.99'
# b'tvmonitor 0.65'
# (2, 4)
# b'person 0.99'
# b'person 0.99'
# (2, 4)
# b'person 0.99'
# b'person 0.99'
# (2, 4)
# b'person 0.99'
# b'person 0.99'
# (2, 4)
# b'person 0.99'
# b'person 0.99'
# (3, 4)
# b'person 0.99'
# b'person 0.99'
# b'tvmonitor 0.93'
# (2, 4)
# b'person 0.99'
# b'person 0.99'
# (3, 4)
# b'person 0.99'
# b'person 0.99'
# b'tvmonitor 0.83'
# (2, 4)
# b'person 0.99'
# b'person 0.99'
# (2, 4)
# b'person 1.00'
# b'person 0.99'
# (3, 4)
# b'person 0.99'
# b'person 0.99'
# b'tvmonitor 0.81'
# (3, 4)
# b'person 1.00'
# b'person 0.99'
# b'tvmonitor 0.84'
# (3, 4)
# b'person 1.00'
# b'person 0.97'
# b'tvmonitor 0.56'
# (3, 4)
# b'person 0.99'
# b'person 0.98'
# b'tvmonitor 0.61'
# (3, 4)
# b'person 1.00'
# b'person 0.99'
# b'tvmonitor 0.86'
# (2, 4)
# b'person 0.99'
# b'person 0.99'
# (3, 4)
# b'person 1.00'
# b'person 0.99'
# b'tvmonitor 0.84'
# (2, 4)
# b'person 1.00'
# b'person 0.99'
# (3, 4)
# b'person 1.00'
# b'person 0.99'
# b'tvmonitor 0.68'
# (2, 4)
# b'person 0.99'
# b'person 0.97'
# (3, 4)
# b'person 0.99'
# b'person 0.98'
# b'tvmonitor 0.69'
# (2, 4)
# b'person 0.99'
# b'person 0.99'
# (3, 4)
# b'person 0.99'
# b'person 0.99'
# b'tvmonitor 0.72'
# (3, 4)
# b'person 0.99'
# b'person 0.98'
# b'tvmonitor 0.57'
# (2, 4)
# b'person 0.99'
# b'person 0.99'
# (1, 4)
# b'person 0.96'
# (1, 4)
# b'person 0.99'
# (2, 4)
# b'person 0.96'
# b'tvmonitor 0.69'
# (1, 4)
# b'person 0.97'
# (2, 4)
# b'person 0.97'
# b'tvmonitor 0.72'
# (2, 4)
# b'person 0.80'
# b'tvmonitor 0.54'
# (1, 4)
# b'person 0.96'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 0.99'
# (2, 4)
# b'person 0.99'
# b'person 0.98'
# (2, 4)
# b'person 0.99'
# b'person 0.95'
# (2, 4)
# b'person 0.99'
# b'person 0.91'
# (2, 4)
# b'person 0.99'
# b'person 0.90'
# (2, 4)
# b'person 0.99'
# b'person 0.90'
# (2, 4)
# b'person 0.99'
# b'person 0.95'
# (3, 4)
# b'person 0.99'
# b'person 0.87'
# b'tvmonitor 0.59'
# (2, 4)
# b'person 1.00'
# b'tvmonitor 0.85'
# (1, 4)
# b'person 1.00'
# (2, 4)
# b'person 1.00'
# b'tvmonitor 0.80'
# (2, 4)
# b'person 1.00'
# b'tvmonitor 0.71'
# (1, 4)
# b'person 1.00'
# (2, 4)
# b'person 1.00'
# b'tvmonitor 0.63'
# (2, 4)
# b'person 1.00'
# b'tvmonitor 0.95'
# (2, 4)
# b'person 1.00'
# b'tvmonitor 0.85'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (2, 4)
# b'person 0.99'
# b'person 0.58'
# (2, 4)
# b'person 0.99'
# b'person 0.76'
# (4, 4)
# b'bottle 0.57'
# b'person 0.99'
# b'person 0.88'
# b'tvmonitor 0.93'
# (3, 4)
# b'person 0.99'
# b'person 0.84'
# b'tvmonitor 0.85'
# (2, 4)
# b'person 0.99'
# b'person 0.90'
# (1, 4)
# b'person 0.94'
# (2, 4)
# b'person 0.96'
# b'person 0.84'
# (2, 4)
# b'person 0.99'
# b'person 0.78'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.61'
# (1, 4)
# b'bicycle 0.67'
# (1, 4)
# b'person 0.68'
# (1, 4)
# b'person 0.76'
# (1, 4)
# b'person 0.50'
# (1, 4)
# b'person 0.75'
# (1, 4)
# b'person 0.72'
# (1, 4)
# b'person 0.79'
# (1, 4)
# b'person 0.89'
# (1, 4)
# b'person 0.58'
# (1, 4)
# b'person 0.59'
# (1, 4)
# b'person 0.61'
# (1, 4)
# b'person 0.93'
# (1, 4)
# b'person 0.51'
# (3, 4)
# b'person 0.83'
# b'tvmonitor 0.97'
# b'tvmonitor 0.79'
# (2, 4)
# b'person 0.98'
# b'person 0.98'
# (2, 4)
# b'person 0.97'
# b'tvmonitor 0.82'
# (2, 4)
# b'person 0.96'
# b'person 0.88'
# (3, 4)
# b'person 0.98'
# b'person 0.87'
# b'tvmonitor 0.53'
# (2, 4)
# b'person 0.99'
# b'person 0.87'
# (1, 4)
# b'person 0.98'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.89'
# (1, 4)
# b'bicycle 0.82'
# (1, 4)
# b'person 0.83'
# (1, 4)
# b'person 0.86'
# (1, 4)
# b'person 0.72'
# (1, 4)
# b'person 0.60'
# (1, 4)
# b'person 0.58'
# (1, 4)
# b'tvmonitor 0.51'
# (1, 4)
# b'person 0.50'
# (1, 4)
# b'tvmonitor 0.51'
# (0, 4)
# (1, 4)
# b'person 0.57'
# (1, 4)
# b'person 0.74'
# (1, 4)
# b'person 0.79'
# (1, 4)
# b'person 0.89'
# (1, 4)
# b'person 0.87'
# (1, 4)
# b'person 0.87'
# (1, 4)
# b'person 0.76'
# (1, 4)
# b'person 0.88'
# (1, 4)
# b'person 0.88'
# (1, 4)
# b'person 0.88'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.97'
# (1, 4)
# b'person 0.96'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.98'
# (1, 4)
# b'person 0.94'
# (1, 4)
# b'person 0.89'
# (1, 4)
# b'person 0.91'
# (1, 4)
# b'person 0.96'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.90'
# (3, 4)
# b'person 1.00'
# b'person 0.99'
# b'tvmonitor 0.97'
# (3, 4)
# b'person 1.00'
# b'person 0.99'
# b'tvmonitor 0.88'
# (3, 4)
# b'person 0.99'
# b'person 0.98'
# b'tvmonitor 0.96'
# (3, 4)
# b'person 0.99'
# b'person 0.98'
# b'tvmonitor 0.97'
# (3, 4)
# b'person 1.00'
# b'person 0.99'
# b'tvmonitor 0.91'
# (3, 4)
# b'person 1.00'
# b'person 0.90'
# b'tvmonitor 0.96'
# (3, 4)
# b'person 1.00'
# b'person 0.94'
# b'tvmonitor 0.98'
# (3, 4)
# b'person 1.00'
# b'person 0.95'
# b'tvmonitor 0.94'
# (3, 4)
# b'person 1.00'
# b'person 0.96'
# b'tvmonitor 0.96'
# (3, 4)
# b'person 1.00'
# b'person 0.77'
# b'tvmonitor 0.92'
# (3, 4)
# b'person 0.99'
# b'person 0.88'
# b'tvmonitor 0.98'
# (3, 4)
# b'person 1.00'
# b'person 0.92'
# b'tvmonitor 0.95'
# (3, 4)
# b'person 1.00'
# b'person 0.87'
# b'tvmonitor 0.96'
# (3, 4)
# b'person 0.99'
# b'person 0.98'
# b'tvmonitor 0.97'
# (3, 4)
# b'person 1.00'
# b'person 0.99'
# b'tvmonitor 0.81'
# (3, 4)
# b'person 1.00'
# b'person 0.99'
# b'tvmonitor 0.90'
# (3, 4)
# b'person 1.00'
# b'person 0.99'
# b'tvmonitor 0.96'
# (3, 4)
# b'person 0.99'
# b'person 1.00'
# b'tvmonitor 0.94'
# (3, 4)
# b'person 0.99'
# b'person 0.99'
# b'tvmonitor 0.97'
# (3, 4)
# b'person 1.00'
# b'person 0.97'
# b'tvmonitor 0.96'
# (3, 4)
# b'person 0.99'
# b'person 0.76'
# b'tvmonitor 0.97'
# (2, 4)
# b'person 1.00'
# b'tvmonitor 0.96'
# (2, 4)
# b'person 1.00'
# b'tvmonitor 0.95'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.98'
# (3, 4)
# b'person 0.99'
# b'person 0.97'
# b'tvmonitor 0.95'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.95'
# (3, 4)
# b'person 0.99'
# b'person 0.54'
# b'tvmonitor 0.90'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.96'
# (2, 4)
# b'bottle 0.73'
# b'person 0.89'
# (3, 4)
# b'bottle 1.00'
# b'person 0.94'
# b'tvmonitor 0.55'
# (3, 4)
# b'person 0.88'
# b'person 0.74'
# b'tvmonitor 0.95'
# (3, 4)
# b'person 0.98'
# b'person 0.64'
# b'tvmonitor 0.96'
# (3, 4)
# b'person 0.96'
# b'person 0.61'
# b'tvmonitor 0.71'
# (3, 4)
# b'person 0.94'
# b'person 0.91'
# b'tvmonitor 0.85'
# (2, 4)
# b'person 0.89'
# b'tvmonitor 0.59'
# (4, 4)
# b'bottle 0.61'
# b'person 0.99'
# b'person 0.61'
# b'tvmonitor 0.87'
# (1, 4)
# b'person 0.99'
# (2, 4)
# b'person 0.99'
# b'person 0.94'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (2, 4)
# b'bottle 0.72'
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (3, 4)
# b'bottle 0.91'
# b'person 0.99'
# b'person 0.92'
# (3, 4)
# b'bottle 0.63'
# b'person 0.99'
# b'tvmonitor 0.88'
# (1, 4)
# b'tvmonitor 0.98'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.92'
# (3, 4)
# b'person 0.99'
# b'person 0.70'
# b'tvmonitor 0.97'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.94'
# (3, 4)
# b'person 0.99'
# b'person 0.88'
# b'tvmonitor 0.88'
# (3, 4)
# b'person 0.99'
# b'person 0.99'
# b'tvmonitor 0.92'
# (3, 4)
# b'person 0.99'
# b'person 0.99'
# b'tvmonitor 0.94'
# (3, 4)
# b'person 0.99'
# b'person 0.90'
# b'tvmonitor 0.98'
# (3, 4)
# b'person 0.99'
# b'person 0.95'
# b'tvmonitor 0.93'
# (3, 4)
# b'person 0.99'
# b'person 0.93'
# b'tvmonitor 0.96'
# (3, 4)
# b'person 0.99'
# b'person 0.86'
# b'tvmonitor 0.95'
# (3, 4)
# b'person 0.99'
# b'person 0.94'
# b'tvmonitor 0.93'
# (3, 4)
# b'person 0.99'
# b'person 0.91'
# b'tvmonitor 0.84'
# (3, 4)
# b'person 0.99'
# b'person 0.82'
# b'tvmonitor 0.87'
# (3, 4)
# b'person 0.99'
# b'person 0.87'
# b'tvmonitor 0.96'
# (3, 4)
# b'person 0.99'
# b'person 0.80'
# b'tvmonitor 0.91'
# (3, 4)
# b'person 0.99'
# b'person 0.82'
# b'tvmonitor 0.91'
# (1, 4)
# b'tvmonitor 0.93'
# (1, 4)
# b'person 0.98'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.91'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.93'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.95'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.91'
# (2, 4)
# b'person 0.98'
# b'tvmonitor 0.90'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.76'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.96'
# (3, 4)
# b'person 0.99'
# b'person 0.50'
# b'tvmonitor 0.98'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.94'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.88'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.92'
# (3, 4)
# b'person 0.99'
# b'person 0.51'
# b'tvmonitor 0.92'
# (3, 4)
# b'person 0.99'
# b'person 0.85'
# b'tvmonitor 0.82'
# (3, 4)
# b'person 0.99'
# b'person 0.88'
# b'tvmonitor 0.95'
# (3, 4)
# b'person 0.99'
# b'person 0.77'
# b'tvmonitor 0.95'
# (3, 4)
# b'person 0.99'
# b'person 0.80'
# b'tvmonitor 0.77'
# (3, 4)
# b'bottle 0.80'
# b'person 0.99'
# b'tvmonitor 0.95'
# (4, 4)
# b'bottle 0.66'
# b'person 0.99'
# b'person 0.74'
# b'tvmonitor 0.97'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.96'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.97'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.92'
# (4, 4)
# b'bottle 0.99'
# b'person 0.99'
# b'person 0.77'
# b'tvmonitor 0.90'
# (3, 4)
# b'person 0.99'
# b'person 0.80'
# b'tvmonitor 0.77'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.89'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.78'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.96'
# (3, 4)
# b'person 0.99'
# b'person 0.63'
# b'tvmonitor 0.83'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.94'
# (3, 4)
# b'person 0.99'
# b'person 0.76'
# b'tvmonitor 0.85'
# (4, 4)
# b'bottle 0.92'
# b'person 0.99'
# b'person 0.77'
# b'tvmonitor 0.71'
# (4, 4)
# b'bottle 0.98'
# b'person 0.99'
# b'person 0.60'
# b'tvmonitor 0.50'
# (4, 4)
# b'bottle 0.96'
# b'person 0.99'
# b'person 0.71'
# b'tvmonitor 0.81'
# (3, 4)
# b'person 0.99'
# b'person 0.57'
# b'tvmonitor 0.70'
# (3, 4)
# b'bottle 1.00'
# b'person 0.99'
# b'tvmonitor 0.81'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.77'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.79'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.98'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.94'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.97'
# (3, 4)
# b'person 0.99'
# b'person 0.66'
# b'tvmonitor 0.67'
# (3, 4)
# b'person 0.99'
# b'person 0.66'
# b'tvmonitor 0.82'
# (3, 4)
# b'person 0.99'
# b'person 0.65'
# b'tvmonitor 0.63'
# (2, 4)
# b'person 0.99'
# b'tvmonitor 0.61'
# (2, 4)
# b'person 0.99'
# b'person 0.84'
# (2, 4)
# b'person 0.96'
# b'person 0.84'
# (2, 4)
# b'person 1.00'
# b'tvmonitor 0.93'
# (3, 4)
# b'person 0.99'
# b'person 0.97'
# b'tvmonitor 0.92'
# (2, 4)
# b'person 0.98'
# b'tvmonitor 0.85'
# (2, 4)
# b'person 0.85'
# b'tvmonitor 0.78'
# (2, 4)
# b'tvmonitor 0.95'
# b'tvmonitor 0.94'
# (1, 4)
# b'tvmonitor 0.87'
# (2, 4)
# b'person 0.84'
# b'tvmonitor 0.69'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 0.98'
# (2, 4)
# b'chair 0.51'
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (2, 4)
# b'chair 0.56'
# b'person 0.99'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (2, 4)
# b'chair 0.90'
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (2, 4)
# b'chair 0.69'
# b'person 1.00'
# (2, 4)
# b'chair 0.52'
# b'person 1.00'
# (2, 4)
# b'chair 0.50'
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (2, 4)
# b'chair 0.58'
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (2, 4)
# b'chair 0.51'
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.91'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.78'
# (1, 4)
# b'bottle 0.51'
# (0, 4)
# (1, 4)
# b'person 0.79'
# (1, 4)
# b'person 0.96'
# (1, 4)
# b'person 0.97'
# (1, 4)
# b'person 0.98'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (2, 4)
# b'chair 0.65'
# b'person 0.99'
# (1, 4)
# b'person 1.00'
# (2, 4)
# b'chair 0.66'
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (2, 4)
# b'person 1.00'
# b'person 0.59'
# (2, 4)
# b'person 1.00'
# b'person 0.73'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (2, 4)
# b'person 1.00'
# b'person 0.64'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (2, 4)
# b'person 0.98'
# b'person 0.79'
# (3, 4)
# b'bottle 0.71'
# b'person 0.80'
# b'person 0.70'
# (2, 4)
# b'bottle 0.68'
# b'person 0.52'
# (1, 4)
# b'person 0.81'
# (1, 4)
# b'person 0.72'
# (1, 4)
# b'person 0.59'
# (1, 4)
# b'person 0.66'
# (1, 4)
# b'person 0.67'
# (2, 4)
# b'bottle 0.54'
# b'person 0.77'
# (1, 4)
# b'person 0.92'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (2, 4)
# b'chair 0.60'
# b'person 0.99'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.94'
# (1, 4)
# b'person 0.62'
# (1, 4)
# b'person 0.95'
# (1, 4)
# b'person 0.86'
# (1, 4)
# b'person 0.98'
# (1, 4)
# b'person 0.94'
# (1, 4)
# b'person 0.98'
# (1, 4)
# b'person 0.82'
# (1, 4)
# b'person 0.81'
# (1, 4)
# b'person 0.64'
# (1, 4)
# b'person 0.67'
# (1, 4)
# b'person 0.63'
# (0, 4)
# (0, 4)
# (1, 4)
# b'person 0.94'
# (1, 4)
# b'person 0.93'
# (1, 4)
# b'person 0.94'
# (1, 4)
# b'person 0.91'
# (1, 4)
# b'person 0.94'
# (1, 4)
# b'person 0.93'
# (1, 4)
# b'person 0.94'
# (1, 4)
# b'person 0.84'
# (1, 4)
# b'tvmonitor 0.94'
# (1, 4)
# b'person 0.52'
# (1, 4)
# b'person 0.87'
# (1, 4)
# b'person 0.79'
# (1, 4)
# b'person 0.90'
# (1, 4)
# b'person 0.95'
# (1, 4)
# b'person 0.92'
# (1, 4)
# b'person 0.93'
# (1, 4)
# b'person 0.89'
# (1, 4)
# b'person 0.90'
# (1, 4)
# b'person 0.97'
# (1, 4)
# b'person 0.98'
# (1, 4)
# b'person 0.98'
# (1, 4)
# b'person 0.95'
# (1, 4)
# b'person 0.96'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 0.98'
# (1, 4)
# b'person 0.68'
# (1, 4)
# b'person 0.81'
# (1, 4)
# b'person 0.76'
# (1, 4)
# b'person 0.91'
# (1, 4)
# b'person 0.81'
# (1, 4)
# b'person 0.65'
# (1, 4)
# b'person 0.73'
# (1, 4)
# b'person 0.92'
# (2, 4)
# b'person 0.85'
# b'tvmonitor 0.72'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.98'
# (1, 4)
# b'person 0.99'
# (2, 4)
# b'person 1.00'
# b'person 0.89'
# (1, 4)
# b'person 0.99'
# (2, 4)
# b'person 0.99'
# b'person 0.81'
# (2, 4)
# b'person 1.00'
# b'person 0.67'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 1.00'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.99'
# (1, 4)
# b'person 0.98'
# (1, 4)
# b'person 0.98'
# (1, 4)
# b'person 0.96'
